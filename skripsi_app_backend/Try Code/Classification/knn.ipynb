# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_digits
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split

# %%
# df = pd.read_csv("../hasil_ekstraksi_rata2_rgb.csv")
# df = pd.read_csv("../hasil_ekstraksi_rata2_hsv.csv")
# df = pd.read_csv("../hasil_ekstraksi_rata2RGB_glcm.csv")
# df = pd.read_csv("../hasil_ekstraksi_orde1_glcm1.csv")
df = pd.read_csv("../hasil_ekstraksi_orde1_glcm.csv")
df
# Out:
#      label  Mean_h    Variance_h  Skewness_h  Kurtosis_h  Entropy_h   Mean_s  \
# 0        1  6480.0  5.076956e+08    5.378715   35.641876   3.003037  4556.25
# 1        1  6480.0  2.088851e+08    2.538185    5.768065   3.619983  4556.25
# 2        1  6480.0  3.022156e+08    5.403765   38.029915   3.640344  4556.25
# 3        1  6480.0  3.010714e+08    4.132243   22.583979   3.384810  4556.25
# 4        1  6480.0  2.622039e+08    3.399756   12.011115   3.579655  4556.25
# ..     ...     ...           ...         ...         ...        ...      ...
# 105      5  6480.0  9.232012e+08    6.882443   48.842202   2.633484  4556.25
# 106      5  6480.0  6.380417e+08    6.637690   51.237317   2.912612  4556.25
# 107      5  6480.0  7.339728e+08    7.866238   68.650359   2.998067  4556.25
# 108      5  6480.0  1.228918e+09   10.855955  130.098630   2.562964  4556.25
# 109      5  6480.0  7.071964e+08    6.264322   43.322146   2.793840  4556.25
#
#       Variance_s  Skewness_s  Kurtosis_s  Entropy_s   Mean_v   Variance_v  \
# 0    121644920.0    5.456260   32.842677   4.453426  4556.25   75501180.0
# 1    129523490.0    5.016876   32.618092   4.161326  4556.25   36053588.0
# 2    106233656.0    4.565187   23.884638   4.462980  4556.25   30451082.0
# 3    216329000.0    6.605473   47.669295   3.959687  4556.25   48963150.0
# 4     66653110.0    3.871840   19.598372   4.624939  4556.25   33396288.0
# ..           ...         ...         ...        ...      ...          ...
# 105  373666700.0    7.781069   67.869030   3.500988  4556.25   79346950.0
# 106  173703890.0    5.741868   36.106716   4.164621  4556.25   53848268.0
# 107  275852350.0    5.575516   31.601305   3.621224  4556.25   95884000.0
# 108  281087170.0    6.001558   36.674872   3.715729  4556.25  121641640.0
# 109  227343360.0    5.935503   35.808009   3.960544  4556.25   94342330.0
#
#      Skewness_v  Kurtosis_v  Entropy_v    Contrast  Homogeneity    Energy
# 0      4.019834   18.217964   4.578484  342.998634     0.344183  0.051767
# 1      1.302771    0.656389   4.722993  188.069927     0.360436  0.040389
# 2      2.382380    7.353843   4.942801  308.761305     0.331347  0.039556
# 3      1.967964    3.320448   4.609291  172.898950     0.366571  0.050431
# 4      1.772093    2.793197   4.847901  277.776157     0.342998  0.048281
# ..          ...         ...        ...         ...          ...       ...
# 105    3.290539   10.470123   4.478579  188.521910     0.328620  0.049430
# 106    2.893539    8.889496   4.651497  337.940455     0.195566  0.032005
# 107    3.692108   13.658637   4.356640  161.106847     0.240024  0.045831
# 108    4.292538   19.120333   4.201531  188.788357     0.393627  0.079371
# 109    3.587785   13.191218   4.317740  298.713959     0.242398  0.049248
#
# [110 rows x 19 columns]

# %%
# Membagi data menjadi data latih dan data uji
X = df.drop(columns="label")
y = df['label']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=None)

# %%
# Membuat objek KNN
knn = KNeighborsClassifier(n_neighbors=3)

# %%
# Melatih model KNN dengan data latih
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
# Membuat prediksi dengan data uji
y_pred = knn.predict(X_test)

# %%
# Menampilkan akurasi model
print("Akurasi: {:.2f}%".format(knn.score(X_test, y_test)*100))
# Out:
# Akurasi: 50.00%
